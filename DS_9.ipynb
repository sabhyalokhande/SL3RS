# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df9=sns.load_dataset('titanic')
df9
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
df9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df9.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.544332    0.523008    0.381594   32.204208
# std      0.486592    0.836071   13.013778    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   29.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df9.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df9['age'] = df9['age'].fillna(int(df9['age'].mean())).astype(int)
df9
# Out:
#      survived  pclass     sex  age  sibsp  parch     fare embarked   class  \
# 0           0       3    male   22      1      0   7.2500        S   Third
# 1           1       1  female   38      1      0  71.2833        C   First
# 2           1       3  female   26      0      0   7.9250        S   Third
# 3           1       1  female   35      1      0  53.1000        S   First
# 4           0       3    male   35      0      0   8.0500        S   Third
# ..        ...     ...     ...  ...    ...    ...      ...      ...     ...
# 886         0       2    male   27      0      0  13.0000        S  Second
# 887         1       1  female   19      0      0  30.0000        S   First
# 888         0       3  female   29      1      2  23.4500        S   Third
# 889         1       1    male   26      0      0  30.0000        C   First
# 890         0       3    male   32      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
df9['embarked'] = df9['embarked'].fillna(df9['embarked'].mode()[0])

# %%
df9['embark_town'] = df9['embark_town'].fillna(df9['embark_town'].mode()[0])

# %%
df9['deck'] = df9['deck'].astype('object')  # Fill missing values as 'Unknown' with dtype 'object'
df9['deck'] = df9['deck'].fillna('Unknown')  # Fill missing values as 'Unknown' with dtype 'object'

# %%
df9.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
numeric_columns=['survived','pclass','age','sibsp','parch','fare']
plt.figure(figsize=(10, 6))
sns.boxplot(data=df9[numeric_columns])
plt.xticks(rotation=45)
plt.title('Boxplot for Numeric Columns')
plt.show()

# %%
Q1 = df9[numeric_columns].quantile(0.25)
Q3 = df9[numeric_columns].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outlier_mask = (df9[numeric_columns] < lower_bound) | (df9[numeric_columns] > upper_bound)

df9_no_outliers = df9[~outlier_mask.any(axis=1)]

print("Dataset before outlier removal:", df9.shape)
print("Dataset after outlier removal:", df9_no_outliers.shape)
# Out:
# Dataset before outlier removal: (891, 15)
# Dataset after outlier removal: (598, 15)

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df9_no_outliers[numeric_columns])
plt.xticks(rotation=45)
plt.title('Boxplot for Numeric Columns')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

numeric_columns=['survived','pclass','age','sibsp','parch','fare']
scaler = MinMaxScaler()
df9[numeric_columns] = scaler.fit_transform(df9[numeric_columns])
df9[numeric_columns].head()
# Out:
#    survived  pclass       age  sibsp  parch      fare
# 0       0.0     1.0  0.271174  0.125    0.0  0.014151
# 1       1.0     0.0  0.472229  0.125    0.0  0.139136
# 2       1.0     1.0  0.321438  0.000    0.0  0.015469
# 3       1.0     0.0  0.434531  0.125    0.0  0.103644
# 4       0.0     1.0  0.434531  0.000    0.0  0.015713

# %%
sns.boxplot(x='survived', y='age', data=df9[df9['sex'] == 'male'])
plt.title("Age Distribution for Male Passengers", fontsize=14)
plt.xlabel("Survival Status", fontsize=12)
plt.ylabel("Age", fontsize=12)
# Out:
# Text(0, 0.5, 'Age')

# %%
plt.subplot(1, 2, 2)  # 1 row, 2 columns, second plot
sns.boxplot(x='survived', y='age', data=df9[df9['sex'] == 'female'], palette='Set2')
plt.title("Age Distribution for Female Passengers", fontsize=14)
plt.xlabel("Survival Status", fontsize=12)
plt.ylabel("Age", fontsize=12)
# Out:
# Text(0, 0.5, 'Age')
